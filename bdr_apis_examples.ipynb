# %%
import pprint, requests

url = 'https://repository.library.brown.edu/api/items/bdr:80246/'

r = requests.get( url )

data_dct: dict = r.json()

pprint.pprint( data_dct )
# Out:
# {'_display_brown_bsi': False,
#  '_display_private_bsi': False,
#  '_display_public_bsi': True,
#  'abstract': ['Interview about Abraham Lincoln.'],
#  'api_links': {'collections': {'Lincoln Broadsides': 'https://repository.library.brown.edu/api/collections/bdr:26147/'},
#                'keywords': {'Childhood and youth': "https://repository.library.brown.edu/api/search/?q='Childhood%20and%20youth'"}},
#  'brief': {'abstract': ['Interview about Abraham Lincoln.'],
#            'contributors': ['McIntyre, Duncan T. (creator)',
#                             'Hanks, Dennis Friend, 1799-1892 (creator)'],
#            'date issued': ['1926'],
#            'extent': ['1 broadside; 54.3 x 40.2 cm.'],
#            'full_title': ['Abe Lincoln as a babe, as a boy and youth: an '
#                           'overlooked interview with Dennis F. Hanks, May '
#                           '1892, a cousin and close companion of Lincoln'],
#            'keywords': ['Childhood and youth'],
#            'notes': ['Includes inset picture and biographical sketch of Dennis '
#                      'F. Hanks; also Gettysburg address',
#                      'Enclosed in border',
#                      'Printed in 3 columns',
#                      'Duncan T. McIntyre, deceased, a Mattoon lawyer, tells it '
#                      "in Dennis F. Hanks' own words ..."],
#            'series': ['http://dl.lib.brown.edu/lincoln/broadsides/index.html'],
#            'subtitle': ['an overlooked interview with Dennis F. Hanks, May '
#                         '1892, a cousin and close companion of Lincoln'],
#            'title': ['Abe Lincoln as a babe, as a boy and youth']},
#  'catalog_links': [],
#  'collection_date': '2012-06-29T00:00:00Z',
#  'collection_title': ['http://dl.lib.brown.edu/lincoln/broadsides/index.html'],
#  'contributor_display': ['McIntyre, Duncan T. (creator)',
#                          'Hanks, Dennis Friend, 1799-1892 (creator)'],
#  'creator': ['McIntyre, Duncan T.', 'Hanks, Dennis Friend'],
#  'creator_string': ['McIntyre, Duncan T.', 'Hanks, Dennis Friend'],
#  'datastreams': {'DC': {'checksum': 'dd14828ed3b01a35501047c4073c66efc73163fc16948609c995b291e962200fe6a0a0a88cea885db8ee33ce3c85298cedeee5045d2c96eaedaac44c20d004ea',
#                         'checksumType': 'SHA-512',
#                         'lastModified': '2012-07-02T08:20:56.482000Z',
#                         'mimeType': 'application/octet-stream',
#                         'size': 1505},
#                  'MASTER': {'checksum': '4c89ce9a0d7ac4c824c38f4e34061112d37ef5a86072b7ab2a96a4178480cfcbcdf6c9c2c292f65f77e162767bd472b92f38574ac825c7ed8b958993b889a4ca',
#                             'checksumType': 'SHA-512',
#                             'lastModified': '2016-07-20T13:39:49.101000Z',
#                             'mimeType': 'image/tiff',
#                             'size': 162761094},
#                  'MODS': {'checksum': '2a40a6b76819db3646a07937f2b23c2f4bfa541465a25801035476fae237435783e3fa94fe78bb9b024149a42e101e9138126c2d42535581beaffa5d026206ce',
#                           'checksumType': 'SHA-512',
#                           'lastModified': '2020-01-29T18:34:02.616000Z',
#                           'mimeType': 'text/xml',
#                           'size': 3710},
#                  'RELS-EXT': {'checksum': '01f955690f9271c40a6d4d970192a05b4fe90ec17ac50bc418c0eb34d982d9c81e25bcdf47fbc3ca05cb060ccff01b995336d169a026a11614cd99830782dbaf',
#                               'checksumType': 'SHA-512',
#                               'lastModified': '2021-11-12T05:44:10.795709Z',
#                               'mimeType': 'text/xml',
#                               'size': 736},
#                  'RELS-INT': {'checksum': '92156b31e96e3bd305e8136dbdcc12ba4d891cb5ffc5aec2c6bdeeb3dc76ce1e8dc79123df01f4c4e037023f6e2e5157e43a5fcdbe39d213d567f741e0a2875a',
#                               'checksumType': 'SHA-512',
#                               'lastModified': '2017-08-07T18:07:01.064000Z',
#                               'mimeType': 'text/xml',
#                               'size': 1057},
#                  'archiveMETS': {'checksum': '82d4b0ce88afa92cd8d47fbe32bad895c6fb8b7bce71aee67a52336cce4129c60b3ca54d4be5cbe2f3dcbf2090bcce69db6511af2007a1db7f7e8d937c0a8b96',
#                                  'checksumType': 'SHA-512',
#                                  'lastModified': '2014-01-25T05:58:07.952000Z',
#                                  'mimeType': 'application/octet-stream',
#                                  'size': 7413},
#                  'highres': {'checksum': 'a62177f6110d0e541847a675b65a73bfdf168316d921883e09afa5db843703f80795e281dca3b762d657b791674d205aab3100c212765fb7b0e93c65deaeba31',
#                              'checksumType': 'SHA-512',
#                              'lastModified': '2012-07-02T08:20:56.494000Z',
#                              'mimeType': 'image/jpeg',
#                              'size': 454713},
#                  'irMetadata': {'checksum': '67bddf4e482f22916a8c30eb42841944a377692293ec8a5884c197c46eae453b4bcc4be0640cf26e244d7f9c96660454576fc45260f50d6e16af33b73e18875d',
#                                 'checksumType': 'SHA-512',
#                                 'lastModified': '2014-01-25T05:58:07.844000Z',
#                                 'mimeType': 'application/octet-stream',
#                                 'size': 629},
#                  'lowres': {'checksum': 'a554da91d6fe35dadcb3da1661d75b87ea808c9ed74265c2bd75929c0d6eb1ce04e3d71260b4e1891d4f5549da995158230db66d5636334177e781bfb64126ed',
#                             'checksumType': 'SHA-512',
#                             'lastModified': '2012-07-02T08:20:56.494000Z',
#                             'mimeType': 'image/jpeg',
#                             'size': 118101},
#                  'rightsMetadata': {'checksum': '82461d13d7eb075723fa4860690b0be3ce70648bbdb627bf72633af59f057b069de6926673918e745beda385ff7784212b4525a34800cb1c9460a610b7004a1f',
#                                     'checksumType': 'SHA-512',
#                                     'lastModified': '2023-02-18T22:02:41.302940Z',
#                                     'mimeType': 'application/octet-stream',
#                                     'size': 1133},
#                  'thumbnail': {'checksum': 'fd7c5d6dedd52b50e3ed71a86f69abdf66a8fcf5502b04af9515013b0d53b9cd00368643f49feed63c30f79a47b776d573d34d346502c30cbd3e357e7dfc1b15',
#                                'checksumType': 'SHA-512',
#                                'lastModified': '2012-07-02T08:20:56.494000Z',
#                                'mimeType': 'image/jpeg',
#                                'size': 13601}},
#  'dateIssued': '1926-01-01T00:00:00Z',
#  'dateIssued_month_ssim': ['01'],
#  'dateIssued_month_text_ssim': ['January'],
#  'dateIssued_year_ssim': ['1926'],
#  'date_dsi': '1926-01-01T00:00:00Z',
#  'deposit_date': '2012-06-29T00:00:00Z',
#  'depositor': 'Center for Digital Scholarship',
#  'depositor_email': 'cds_info@brown.edu',
#  'display_inline': '<iframe name="contentIframe" '
#                    'src="https://repository.library.brown.edu/viewers/image/zoom/bdr:80246/" '
#                    'width="100%" height="800" frameborder="0" '
#                    'webkitallowfullscreen mozallowfullscreen '
#                    'allowfullscreen></iframe>',
#  'display_inline_src': 'https://repository.library.brown.edu/viewers/image/zoom/bdr:80246/',
#  'fed_created_dsi': '2012-07-02T08:20:56.449Z',
#  'fed_last_modified_dsi': '2023-02-18T22:02:41.302Z',
#  'fed_object_size_lsi': 163363692,
#  'genre': ['broadsides'],
#  'genre_aat': ['broadsides'],
#  'identifier': ['226205'],
#  'iiif_resource_bsi': True,
#  'ir_collection_id': [575],
#  'ir_collection_name': ['Brown University Library', 'Lincoln Broadsides'],
#  'json_uri': 'https://repository.library.brown.edu/api/items/bdr:80246/',
#  'keyword': ['Childhood and youth'],
#  'links': {'collections': {'Lincoln Broadsides': 'https://repository.library.brown.edu/studio/collections/bdr:26147/'},
#            'content_datastreams': {'highres': 'https://repository.library.brown.edu/storage/bdr:80246/highres/',
#                                    'lowres': 'https://repository.library.brown.edu/storage/bdr:80246/lowres/'},
#            'descriptive_datastreams': {'MODS': 'https://repository.library.brown.edu/storage/bdr:80246/MODS/'},
#            'keywords': {'Childhood and youth': 'https://repository.library.brown.edu/studio/search/?q="Childhood '
#                                                'and youth"'},
#            'media_streams': [],
#            'thumbnail': 'https://repository.library.brown.edu/viewers/image/thumbnail/bdr:80246/',
#            'views': {'Detailed Image Viewer': 'https://repository.library.brown.edu/viewers/image/zoom/bdr:80246/',
#                      'Medium Resolution': 'https://repository.library.brown.edu/viewers/image/medium/bdr:80246/',
#                      'Mirador Viewer': 'https://repository.library.brown.edu/viewers/mirador/bdr:80246/',
#                      'Universal Viewer': 'https://repository.library.brown.edu/viewers/universal/bdr:80246/',
#                      'iiif_image_info': 'https://repository.library.brown.edu/iiif/image/bdr:80246/info.json',
#                      'iiif_manifest': 'https://repository.library.brown.edu/iiif/presentation/bdr:80246/manifest.json'}},
#  'mets_id': '1201795805609375',
#  'mods_abstract_ssim': ['Interview about Abraham Lincoln.'],
#  'mods_access_condition_restriction_text_tsim': ['Collection is open for '
#                                                  'research.'],
#  'mods_access_condition_rights_link_ssim': ['http://rightsstatements.org/vocab/InC/1.0/'],
#  'mods_access_condition_rights_text_tsim': ['In Copyright'],
#  'mods_collection_id': ['22'],
#  'mods_dateAll_ssim': ['1926'],
#  'mods_dateAll_year_ssim': ['1926'],
#  'mods_dateIssued_ssim': ['1926'],
#  'mods_genre_aat_ssim': ['broadsides'],
#  'mods_id': 'libr001868',
#  'mods_id_hay_lincoln_broadsides_ssim': ['226205'],
#  'mods_id_local_ssim': ['226205'],
#  'mods_id_mets_ssi': '1201795805609375',
#  'mods_language_code_ssim': ['eng'],
#  'mods_language_ssim': ['eng'],
#  'mods_name_nonplace_ssim': ['McIntyre, Duncan T.', 'Hanks, Dennis Friend'],
#  'mods_note_statement_of_responsibility_ssim': ['Duncan T. McIntyre, deceased, '
#                                                 'a Mattoon lawyer, tells it in '
#                                                 "Dennis F. Hanks' own words "
#                                                 '...'],
#  'mods_physicalDescription_digitalOrigin_ssim': ['reformatted digital'],
#  'mods_physicalDescription_extent_ssim': ['1 broadside; 54.3 x 40.2 cm.'],
#  'mods_publisher_ssim': ['T.B. & Son'],
#  'mods_related_id_colid_ssim': ['22'],
#  'mods_related_id_uri_ssim': ['Lincoln Broadsides'],
#  'mods_role_creator_ssim': ['McIntyre, Duncan T.', 'Hanks, Dennis Friend'],
#  'mods_role_ssim': ['creator'],
#  'mods_subject_joined_ssim': ['Lincoln, Abraham > 1809-1865 > Childhood and '
#                               'youth',
#                               'Gettysburg address'],
#  'mods_subject_ssim': ['Childhood and youth'],
#  'mods_subject_title_ssim': ['Gettysburg address'],
#  'mods_title_full_primary_tsi': 'Abe Lincoln as a babe, as a boy and youth: an '
#                                 'overlooked interview with Dennis F. Hanks, '
#                                 'May 1892, a cousin and close companion of '
#                                 'Lincoln',
#  'mods_title_full_tsim': ['Abe Lincoln as a babe, as a boy and youth: an '
#                           'overlooked interview with Dennis F. Hanks, May '
#                           '1892, a cousin and close companion of Lincoln',
#                           'Shelby County Leader'],
#  'mods_title_full_uniform_tsim': ['Shelby County Leader'],
#  'mods_type_of_resource': ['still image'],
#  'name': ['McIntyre, Duncan T.', 'Hanks, Dennis Friend'],
#  'note': ['Includes inset picture and biographical sketch of Dennis F. Hanks; '
#           'also Gettysburg address',
#           'Enclosed in border',
#           'Printed in 3 columns',
#           'Duncan T. McIntyre, deceased, a Mattoon lawyer, tells it in Dennis '
#           "F. Hanks' own words ..."],
#  'object_created_dsi': '2012-07-02T08:20:56.449Z',
#  'object_last_modified_dsi': '2023-02-18T22:02:41.302Z',
#  'object_size_lsi': 163363692,
#  'object_type': 'image',
#  'other_title': ['Gettysburg address', 'Shelby County Leader'],
#  'pid': 'bdr:80246',
#  'primary_download_link': 'https://repository.library.brown.edu/viewers/image/zoom/bdr:80246/',
#  'primary_title': 'Abe Lincoln as a babe, as a boy and youth',
#  'primary_title_txt_en_split': 'Abe Lincoln as a babe, as a boy and youth',
#  'publisher': ['T.B. & Son'],
#  'rel_content_models_ssim': ['commonMetadata',
#                              'image-compound',
#                              'archiveMETS',
#                              'masterImage'],
#  'rel_is_member_of_collection_ssim': ['bdr:26147'],
#  'rel_object_type_ssi': 'image',
#  'relations': {'hasAnnotation': [],
#                'hasDerivation': [],
#                'hasDescription': [],
#                'hasPart': [],
#                'hasTranscript': [],
#                'hasTranslation': [],
#                'isDerivationOf': [],
#                'isMemberOf': [],
#                'isMemberOfCollection': [{'ancestors': ['Brown University '
#                                                        'Library'],
#                                          'child_folders': [],
#                                          'db_id': 575,
#                                          'description': "Brown's Lincoln "
#                                                         'Broadsides collection '
#                                                         'comprises an '
#                                                         'assortment of printed '
#                                                         'materials intended '
#                                                         'for broad public '
#                                                         'distribution in a '
#                                                         'variety of formats. '
#                                                         'Within this digital '
#                                                         'collection you will '
#                                                         'find, for example: '
#                                                         'handbills (a single '
#                                                         'sheet of text '
#                                                         'intended for wide '
#                                                         'public distribution), '
#                                                         'leaftlets (a handbill '
#                                                         'folded to create '
#                                                         'multiple leaves), '
#                                                         'small pamphlets '
#                                                         '(unbound booklets, '
#                                                         'typically stapled or '
#                                                         'sewn), souvenir '
#                                                         'cards, circulars, '
#                                                         'broadsheets, '
#                                                         'brochures.  These '
#                                                         'materials encompass a '
#                                                         'relatively wide range '
#                                                         'of content and often '
#                                                         'incorporate graphic '
#                                                         'images as an adjunct '
#                                                         'to printed text. They '
#                                                         'range in date from '
#                                                         'the 1840s through the '
#                                                         '1920s, and cover both '
#                                                         'events in which '
#                                                         'Lincoln was actually '
#                                                         'involved and those '
#                                                         'that revolved around '
#                                                         'the use of his public '
#                                                         'image.',
#                                          'id': 'bdr:26147',
#                                          'json_uri': 'https://repository.library.brown.edu/api/collections/bdr:26147/',
#                                          'name': 'Lincoln Broadsides',
#                                          'parent_folders': [{'db_id': 468,
#                                                              'description': 'The '
#                                                                             'Brown '
#                                                                             'University '
#                                                                             'Library, '
#                                                                             'in '
#                                                                             'support '
#                                                                             'of '
#                                                                             'the '
#                                                                             "University's "
#                                                                             'educational '
#                                                                             'and '
#                                                                             'research '
#                                                                             'mission, '
#                                                                             'is '
#                                                                             'the '
#                                                                             'local '
#                                                                             'repository '
#                                                                             'for '
#                                                                             'and '
#                                                                             'the '
#                                                                             'principal '
#                                                                             'gateway '
#                                                                             'to '
#                                                                             'current '
#                                                                             'information '
#                                                                             'and '
#                                                                             'the '
#                                                                             'scholarly '
#                                                                             'record. \r\n'
#                                                                             '\r\n'
#                                                                             'As '
#                                                                             'such, '
#                                                                             'it '
#                                                                             'is '
#                                                                             'simultaneously '
#                                                                             'collection, '
#                                                                             'connection, '
#                                                                             'and '
#                                                                             'classroom, '
#                                                                             'primarily '
#                                                                             'for '
#                                                                             'the '
#                                                                             'current '
#                                                                             'and '
#                                                                             'future '
#                                                                             'students '
#                                                                             'and '
#                                                                             'faculty '
#                                                                             'of '
#                                                                             'the '
#                                                                             'University, '
#                                                                             'while '
#                                                                             'also '
#                                                                             'serving '
#                                                                             'other '
#                                                                             'colleagues '
#                                                                             'in '
#                                                                             'the '
#                                                                             'University '
#                                                                             'community '
#                                                                             'and '
#                                                                             'our '
#                                                                             'regional, '
#                                                                             'national, '
#                                                                             'and '
#                                                                             'global '
#                                                                             'communities '
#                                                                             'of '
#                                                                             'learning '
#                                                                             'and '
#                                                                             'scholarship.',
#                                                              'id': 'bdr:qpubn7sw',
#                                                              'json_uri': 'https://repository.library.brown.edu/api/collections/bdr:qpubn7sw/',
#                                                              'name': 'Brown '
#                                                                      'University '
#                                                                      'Library',
#                                                              'pid': 'bdr:qpubn7sw',
#                                                              'tags': [],
#                                                              'thumbnail_url': 'https://repository.library.brown.edu/storage/bdr:qpubn7sw/thumbnail/',
#                                                              'uri': 'https://repository.library.brown.edu/studio/collections/bdr:qpubn7sw/'}],
#                                          'pid': 'bdr:26147',
#                                          'tags': [],
#                                          'thumbnail_url': 'https://repository.library.brown.edu/storage/bdr:26147/thumbnail/',
#                                          'uri': 'https://repository.library.brown.edu/studio/collections/bdr:26147/'}],
#                'isPartOf': [],
#                'isTranscriptOf': [],
#                'isTranslationOf': [],
#                'isVersionOf': []},
#  'resource_type_ssi': 'images',
#  'storage_location_ssi': 'ocfl',
#  'subject': ['Lincoln, Abraham', 'Gettysburg address'],
#  'subtitle': ['an overlooked interview with Dennis F. Hanks, May 1892, a '
#               'cousin and close companion of Lincoln'],
#  'thumbnail': 'https://repository.library.brown.edu/viewers/image/thumbnail/bdr:80246/',
#  'timestamp': '2023-02-18T22:50:49.933Z',
#  'title_si': 'Abe Lincoln as a babe, as a boy and youth',
#  'uri': 'https://repository.library.brown.edu/studio/item/bdr:80246/',
#  'views_dict': {'Detailed Image Viewer': 'https://repository.library.brown.edu/viewers/image/zoom/bdr:80246/',
#                 'Medium Resolution': 'https://repository.library.brown.edu/viewers/image/medium/bdr:80246/',
#                 'Mirador Viewer': 'https://repository.library.brown.edu/viewers/mirador/bdr:80246/',
#                 'Universal Viewer': 'https://repository.library.brown.edu/viewers/universal/bdr:80246/',
#                 'iiif_image_info': 'https://repository.library.brown.edu/iiif/image/bdr:80246/info.json',
#                 'iiif_manifest': 'https://repository.library.brown.edu/iiif/presentation/bdr:80246/manifest.json'}}
